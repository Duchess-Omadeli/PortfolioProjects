# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as py
from bs4 import BeautifulSoup
import requests
import seaborn as sns
print("ready")
# Out:
# ready

# %%
sns?
# Out:
# Type:        module
# String form: <module 'seaborn' from 'C:\\Users\\LENOVO\\anaconda3\\lib\\site-packages\\seaborn\\__init__.py'>
# File:        c:\users\lenovo\anaconda3\lib\site-packages\seaborn\__init__.py
# Docstring:   <no docstring>

# %%
import urllib.request

# %%
data='./Documents/PROJECTHIIT/africa_food_prices.csv'

# %%
my_food_url = pd.read_csv(data, header = 0)

my_food_url.head()
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# ...

# %%
my_food_url.tail()
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# 956774  Mbilashaba         432   Beans (sugar) - Retail          0.0      ZWL
# 956775  Mbilashaba         539      Toothpaste - Retail          0.0      ZWL
# 956776  Mbilashaba         540    Laundry soap - Retail          0.0      ZWL
# 956777  Mbilashaba         541   Handwash soap - Retail          0.0      ZWL
# 956778  Mbilashaba         887  Fish (kapenta) - Retail          0.0      ZWL
#
# ...

# %%
df= my_food_url.copy() #DEEP COPY

df.head(6)
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
# 5       15432         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
# ...

# %%
df
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   country             956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   market              956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   produce             956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  currency            956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_unit_id          956779 non-null  int64
#  14  quantity            956779 non-null  object
# ...

# %%
df.shape
# Out:
# (956779, 19)

# %%
df.columns #number of columns
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
cols_to_drop = ['country_id', 'state_id','market_id','produce_id','currency_id','pt_id','um_unit_id','mp_commoditysource'] #drop the id's
newdf= df.drop(columns = cols_to_drop,axis=1)

# %%
newdf
# Out:
#         Unnamed: 0   country     state      market                  produce  \
# 0            15427   Algeria     Alger     Algiers            Rice - Retail
# 1            15428   Algeria     Alger     Algiers            Rice - Retail
# 2            15429   Algeria     Alger     Algiers            Rice - Retail
# 3            15430   Algeria     Alger     Algiers            Rice - Retail
# 4            15431   Algeria     Alger     Algiers            Rice - Retail
# ...            ...       ...       ...         ...                      ...
# 956774     2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar) - Retail
# 956775     2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste - Retail
# 956776     2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap - Retail
# 956777     2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap - Retail
# 956778     2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta) - Retail
#
# ...

# %%
newdf.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0   country     state      market                  produce  \
# 0            15427   Algeria     Alger     Algiers            Rice - Retail
# 1            15428   Algeria     Alger     Algiers            Rice - Retail
# 2            15429   Algeria     Alger     Algiers            Rice - Retail
# 3            15430   Algeria     Alger     Algiers            Rice - Retail
# 4            15431   Algeria     Alger     Algiers            Rice - Retail
# ...            ...       ...       ...         ...                      ...
# 956774     2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar) - Retail
# 956775     2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste - Retail
# 956776     2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap - Retail
# 956777     2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap - Retail
# 956778     2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta) - Retail
#
# ...

# %%
newdf.columns
# Out:
# Index(['Unnamed: 0', 'country', 'state', 'market', 'produce', 'currency',
#        'market_type', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
#RENAMING COLUMNS
newdf = newdf.rename(columns={
    newdf.columns[0]: 'S/N',
    newdf.columns[1]: 'country',
    newdf.columns[2]: 'state',
    newdf.columns[3]: 'market',
    newdf.columns[4]: 'produce',
    newdf.columns[5]: 'type of currency'
    
})

# %%
newdf.head()
# Out:
#      S/N  country  state   market        produce type of currency market_type  \
# 0  15427  Algeria  Alger  Algiers  Rice - Retail              DZD      Retail
# 1  15428  Algeria  Alger  Algiers  Rice - Retail              DZD      Retail
# 2  15429  Algeria  Alger  Algiers  Rice - Retail              DZD      Retail
# 3  15430  Algeria  Alger  Algiers  Rice - Retail              DZD      Retail
# 4  15431  Algeria  Alger  Algiers  Rice - Retail              DZD      Retail
#
#   quantity  month  year  price
# 0       KG      4  2015   90.0
# 1       KG      5  2015   96.0
# 2       KG      6  2015   96.0
# 3       KG      7  2015   83.0
# 4       KG      8  2015   80.0

# %%
newdf.columns
# Out:
# Index(['S/N', 'country', 'state', 'market', 'produce', 'type of currency',
#        'market_type', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
newdf['produce']
# Out:
# 0                   Rice - Retail
# 1                   Rice - Retail
# 2                   Rice - Retail
# 3                   Rice - Retail
# 4                   Rice - Retail
#                    ...
# 956774     Beans (sugar) - Retail
# 956775        Toothpaste - Retail
# 956776      Laundry soap - Retail
# 956777     Handwash soap - Retail
# 956778    Fish (kapenta) - Retail
# Name: produce, Length: 956779, dtype: object

# %%
#SPLIT A DELIMETER
print(type(newdf['produce'][0]))
# Out:
# <class 'str'>

# %%
print(newdf['produce'][0])
# Out:
# Rice - Retail

# %%
#split at delimeter(-)
temp = newdf[ 'produce'].str.split("-", n=1, expand = True)

# %%
temp
# Out:
#                       0        1
# 0                 Rice    Retail
# 1                 Rice    Retail
# 2                 Rice    Retail
# 3                 Rice    Retail
# 4                 Rice    Retail
# ...                 ...      ...
# 956774   Beans (sugar)    Retail
# 956775      Toothpaste    Retail
# 956776    Laundry soap    Retail
# 956777   Handwash soap    Retail
# 956778  Fish (kapenta)    Retail
#
# [956779 rows x 2 columns]

# %%
newdf['produce'] = temp[0]

# %%
newdf.head()
# Out:
#      S/N  country  state   market produce type of currency market_type  \
# 0  15427  Algeria  Alger  Algiers   Rice               DZD      Retail
# 1  15428  Algeria  Alger  Algiers   Rice               DZD      Retail
# 2  15429  Algeria  Alger  Algiers   Rice               DZD      Retail
# 3  15430  Algeria  Alger  Algiers   Rice               DZD      Retail
# 4  15431  Algeria  Alger  Algiers   Rice               DZD      Retail
#
#   quantity  month  year  price
# 0       KG      4  2015   90.0
# 1       KG      5  2015   96.0
# 2       KG      6  2015   96.0
# 3       KG      7  2015   83.0
# 4       KG      8  2015   80.0

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   S/N               956779 non-null  int64
#  1   country           956779 non-null  object
#  2   state             830101 non-null  object
#  3   market            956779 non-null  object
#  4   produce           956779 non-null  object
#  5   type of currency  956779 non-null  object
#  6   market_type       956779 non-null  object
#  7   quantity          956779 non-null  object
#  8   month             956779 non-null  int64
#  9   year              956779 non-null  int64
#  10  price             956779 non-null  float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 80.3+ MB

# %%
newdf.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad',)
# Out:
#             S/N   country     state      market          produce  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        type of currency market_type quantity  month  year      price
# 0                   DZD      Retail       KG      4  2015    90.0000
# ...

# %%
newdf['quantity'] = newdf['quantity'].replace('KG','1KG')
print(newdf)
# Out:
#             S/N   country     state      market          produce  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        type of currency market_type quantity  month  year      price
# 0                   DZD      Retail      1KG      4  2015    90.0000
# ...

# %%
newdf.head()
# Out:
#      S/N  country  state   market produce type of currency market_type  \
# 0  15427  Algeria  Alger  Algiers   Rice               DZD      Retail
# 1  15428  Algeria  Alger  Algiers   Rice               DZD      Retail
# 2  15429  Algeria  Alger  Algiers   Rice               DZD      Retail
# 3  15430  Algeria  Alger  Algiers   Rice               DZD      Retail
# 4  15431  Algeria  Alger  Algiers   Rice               DZD      Retail
#
#   quantity  month  year  price
# 0      1KG      4  2015   90.0
# 1      1KG      5  2015   96.0
# 2      1KG      6  2015   96.0
# 3      1KG      7  2015   83.0
# 4      1KG      8  2015   80.0

# %%
newdf['quantity'] = newdf['quantity'].replace('USD/LCU','USD')
print(newdf)
# Out:
#             S/N   country     state      market          produce  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        type of currency market_type quantity  month  year      price
# 0                   DZD      Retail      1KG      4  2015    90.0000
# ...

# %%
#Convert python file to accessible Csv file
newdf.to_csv('./Documents/PROJECTHIIT/africa_food_prices_newest.csv',index = False)

# %%
africa_food_new = pd.read_csv('./Documents/PROJECTHIIT/africa_food_prices_newest.csv')

# %%
africa_food_new.head()
# Out:
#      S/N  country  state   market produce type of currency market_type  \
# 0  15427  Algeria  Alger  Algiers   Rice               DZD      Retail
# 1  15428  Algeria  Alger  Algiers   Rice               DZD      Retail
# 2  15429  Algeria  Alger  Algiers   Rice               DZD      Retail
# 3  15430  Algeria  Alger  Algiers   Rice               DZD      Retail
# 4  15431  Algeria  Alger  Algiers   Rice               DZD      Retail
#
#   quantity  month  year  price
# 0      1KG      4  2015   90.0
# 1      1KG      5  2015   96.0
# 2      1KG      6  2015   96.0
# 3      1KG      7  2015   83.0
# 4      1KG      8  2015   80.0

# %% [markdown]
# # FILTERING COUNTRY

# %%
print(africa_food_new['country'])
# Out:
# 0          Algeria
# 1          Algeria
# 2          Algeria
# 3          Algeria
# 4          Algeria
#             ...
# 956774    Zimbabwe
# 956775    Zimbabwe
# 956776    Zimbabwe
# 956777    Zimbabwe
# 956778    Zimbabwe
# Name: country, Length: 956779, dtype: object

# %%
print(africa_food_new['country'][0])
# Out:
# Algeria

# %%
print("No of rows: ",africa_food_new.shape[0])
print("No of cols: ",africa_food_new.shape[1])
# Out:
# No of rows:  956779
# No of cols:  11

# %%
#To find empty rows and null values

newdf.isnull().sum()
# Out:
# S/N                      0
# country                  0
# state               126678
# market                   0
# produce                  0
# type of currency         0
# market_type              0
# quantity                 0
# month                    0
# year                     0
# price                    0
# dtype: int64

# %%
newdf = newdf.dropna(subset = ['state'])

# %%
newdf.isnull().sum()
# Out:
# S/N                 0
# country             0
# state               0
# market              0
# produce             0
# type of currency    0
# market_type         0
# quantity            0
# month               0
# year                0
# price               0
# dtype: int64

# %% [markdown]
# # I AM FILTERING THROUGH GHANA AND CREATING PIVOT CHARTS

# %%
country_list = ['Ghana']
africa_food_new[africa_food_new.country.isin(country_list)]
# Out:
#            S/N country    state            market                 produce  \
# 255512  610316   Ghana  Ashanti            Kumasi                  Maize
# 255513  610317   Ghana  Ashanti            Kumasi                  Maize
# 255514  610318   Ghana  Ashanti            Kumasi                  Maize
# 255515  610319   Ghana  Ashanti            Kumasi                  Maize
# 255516  610320   Ghana  Ashanti            Kumasi                  Maize
# ...        ...     ...      ...               ...                     ...
# 280921  635725   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280922  635726   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280923  635727   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280924  635728   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280925  635729   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
#
#        type of currency market_type quantity  month  year   price
# ...

# %%
africa_food_new.columns
# Out:
# Index(['S/N', 'country', 'state', 'market', 'produce', 'type of currency',
#        'market_type', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
ghana_foods = africa_food_new[africa_food_new.country.isin(country_list)]

# %%
ghana_foods.head()
# Out:
#            S/N country    state  market produce type of currency market_type  \
# 255512  610316   Ghana  Ashanti  Kumasi  Maize               GHS   Wholesale
# 255513  610317   Ghana  Ashanti  Kumasi  Maize               GHS   Wholesale
# 255514  610318   Ghana  Ashanti  Kumasi  Maize               GHS   Wholesale
# 255515  610319   Ghana  Ashanti  Kumasi  Maize               GHS   Wholesale
# 255516  610320   Ghana  Ashanti  Kumasi  Maize               GHS   Wholesale
#
#        quantity  month  year  price
# 255512   100 KG      1  2006  25.40
# 255513   100 KG      2  2006  21.75
# 255514   100 KG      3  2006  21.21
# 255515   100 KG      4  2006  20.88
# 255516   100 KG      5  2006  22.00

# %%
ghana_foods.tail()
# Out:
#            S/N country    state            market                 produce  \
# 280921  635725   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280922  635726   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280923  635727   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280924  635728   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 280925  635729   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
#
#        type of currency market_type quantity  month  year   price
# 280921              GHS   Wholesale    10 KG      3  2021  317.89
# 280922              GHS   Wholesale    10 KG      4  2021  326.97
# 280923              GHS   Wholesale    10 KG      5  2021  302.83
# 280924              GHS   Wholesale    10 KG      6  2021  321.08
# 280925              GHS   Wholesale    10 KG      7  2021  320.54

# %%
ghana_foods.columns
# Out:
# Index(['S/N', 'country', 'state', 'market', 'produce', 'type of currency',
#        'market_type', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %% [markdown]
# # FIVE RESEARCH QUESTIONS

# %%
# 1. WHAT ARE THE DIFFERENT PRODUCTS SOLD ?

# %%
# 2. WHICH MARKET TYPE IS MORE SATURATED BETWEEN WHOLESALE OR RETAIL?

# %%
# 3. WHAT IS THE NUMBER OF SALES OF EACH PRODUCT?

# %%
# 4. WHICH STATE HAS MORE SALES?

# %%
# 5. WHAT YEAR RECORDED THE HIGHEST AMOUNT OF SALES?

# %%
ghana_foods['produce'].unique()
# Out:
# array(['Maize ', 'Gari ', 'Rice (imported) ', 'Sorghum ', 'Cassava ',
#        'Rice (local) ', 'Millet ', 'Eggs ', 'Meat (chicken) ',
#        'Plantains (apentu) ', 'Yam ', 'Maize (yellow) ', 'Onions ',
#        'Rice (paddy) ', 'Cowpeas ', 'Soybeans ', 'Tomatoes (local) ',
#        'Eggplants ', 'Cowpeas (white) ', 'Plantains (apem) ',
#        'Tomatoes (navrongo) ', 'Peppers (fresh) ', 'Peppers (dried) ',
#        'Yam (puna) ', 'Fish (mackerel, fresh) ', 'Meat (chicken, local) '],
#       dtype=object)

# %%
ghana_foods.market_type.value_counts()
# Out:
# Wholesale    18231
# Retail        7183
# Name: market_type, dtype: int64

# %%
pd.pivot_table(ghana_foods, index = "market_type")
# Out:
#                        S/N     month       price         year
# market_type
# Retail       623625.268551  6.377837    4.739632  2020.068495
# Wholesale    622785.009654  6.373375  147.103357  2014.821074

# %%
ghana_foods.groupby("market_type")["produce"].first()
# Out:
# market_type
# Retail       Maize
# Wholesale    Maize
# Name: produce, dtype: object

# %%
ghana_foods.groupby("market_type")["produce"].last()
# Out:
# market_type
# Retail       Fish (mackerel, fresh)
# Wholesale     Meat (chicken, local)
# Name: produce, dtype: object

# %%
temp = ghana_foods.market_type.value_counts()
temp.plot(kind='bar')
py.title("Market Type Distribution")
py.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ghana_foods_grouped=ghana_foods.groupby('produce').size().reset_index(name='produce_count')

# %%
ghana_foods_merged=pd.merge(ghana_foods,ghana_foods_grouped,on='produce', how='left')

# %%
ghana_foods_merged
# Out:
#           S/N country    state            market                 produce  \
# 0      610316   Ghana  Ashanti            Kumasi                  Maize
# 1      610317   Ghana  Ashanti            Kumasi                  Maize
# 2      610318   Ghana  Ashanti            Kumasi                  Maize
# 3      610319   Ghana  Ashanti            Kumasi                  Maize
# 4      610320   Ghana  Ashanti            Kumasi                  Maize
# ...       ...     ...      ...               ...                     ...
# 25409  635725   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 25410  635726   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 25411  635727   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 25412  635728   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
# 25413  635729   Ghana  Western  Sekondi/Takoradi  Meat (chicken, local)
#
#       type of currency market_type quantity  month  year   price  \
# ...

# %%
pd.pivot_table(ghana_foods_merged, index = "produce")
# Out:
#                                    S/N     month       price  produce_count  \
# produce
# Cassava                  622193.579555  6.425392   63.106473           2426
# Cowpeas                  624025.065421  6.635514    3.601558            321
# Cowpeas (white)          623850.160714  5.773810  340.354732            168
# Eggplants                623891.909910  6.409009   73.480045            555
# Eggs                     622775.009132  6.365297  225.537854            219
# Fish (mackerel, fresh)   623888.280460  6.632184  130.352046            435
# Gari                     622458.182759  6.198276  115.326664            580
# Maize                    622401.105994  6.382310   87.333604           2736
# Maize (yellow)           623217.133333  6.398333   81.318242            600
# Meat (chicken)           623418.366162  5.674242  113.829116            396
# Meat (chicken, local)    623000.045455  6.530303  159.621187            198
# ...

# %%
ghana_foods.produce.value_counts()
# Out:
# Maize                      2736
# Yam                        2496
# Cassava                    2426
# Rice (local)               2396
# Plantains (apentu)         2307
# Rice (imported)            1905
# Millet                     1582
# Sorghum                    1560
# Maize (yellow)              600
# Plantains (apem)            596
# Gari                        580
# Eggplants                   555
# Yam (puna)                  554
# Tomatoes (navrongo)         536
# Onions                      535
# Peppers (fresh)             511
# Soybeans                    505
# Tomatoes (local)            476
# Peppers (dried)             466
# Fish (mackerel, fresh)      435
# Meat (chicken)              396
# Rice (paddy)                355
# Cowpeas                     321
# Eggs                        219
# Meat (chicken, local)       198
# Cowpeas (white)             168
# Name: produce, dtype: int64

# %%
temp = ghana_foods.produce.value_counts()

# %%
temp.plot(kind='bar')
py.title("State Distribution")
py.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
temp = ghana_foods.state.value_counts()
temp.plot(kind='barh')
py.title("AMOUNT OF SALE IN EACH STATE")
py.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
year_graph= ghana_foods['year'].plot(kind = 'hist')
py.title("AMOUNT OF SALE PER YEAR")
py.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
